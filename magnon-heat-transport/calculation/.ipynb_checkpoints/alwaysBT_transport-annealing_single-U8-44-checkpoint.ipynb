# %%
# %reload_ext autoreload
# %autoreload 2

from packages.correlations import *
from packages.modelfunction import *

# %%
U=8
sitex = 8
sitey = 8
bs=200
tp=0


w = np.load(f"wU={U:g}.npy")
dw = np.load(f"dwU={U:g}.npy")

prefix = "n1_annealing_single_alwaysBT"

jeje = np.load(prefix+f"jejeU{U:g}tp{tp:g}_{sitex:g}*{sitey:g}.npy")
jkjk = np.load(prefix+f"jkjkU{U:g}tp{tp:g}_{sitex:g}*{sitey:g}.npy")
jpjp = np.load(prefix+f"jpjpU{U:g}tp{tp:g}_{sitex:g}*{sitey:g}.npy")
j0j0 = np.load(prefix+f"j0j0U{U:g}tp{tp:g}_{sitex:g}*{sitey:g}.npy")

i=0
mdljeje,mdljkjk,mdljpjp,mdlj0j0,= \
jeje[i, 8]*dw/(jeje[i, 8]*dw).sum()+ np.nextafter(0, 1), \
jkjk[i, 8]*dw/(jkjk[i, 8]*dw).sum()+ np.nextafter(0, 1), \
jpjp[i, 8]*dw/(jpjp[i, 8]*dw).sum()+ np.nextafter(0, 1), \
j0j0[i, 8]*dw/(j0j0[i, 8]*dw).sum()+ np.nextafter(0, 1), 

mdls = (mdljeje,mdljkjk,mdljpjp,mdlj0j0)


sitex = 4
sitey = 4


ns = np.array([1])
betas = np.array([2,2.5,3,3.5,4,4.5,5,6,7,8,10])


jeje =np.zeros((len(ns), len(betas), len(w)))
jkjk =np.zeros((len(ns), len(betas), len(w)))
jpjp =np.zeros(( len(ns), len(betas), len(w)))
j0j0 =np.zeros(( len(ns), len(betas), len(w)))
C =np.zeros(( len(ns), len(betas)))
chi =np.zeros(( len(ns), len(betas)))

jejes = np.zeros(( len(ns), len(betas), bs,len(w)))
jkjks =np.zeros(( len(ns), len(betas), bs,len(w)))
jpjps = np.zeros(( len(ns), len(betas), bs,len(w)))
j0j0s = np.zeros(( len(ns), len(betas), bs,len(w)))
Cs = np.zeros(( len(ns), len(betas), bs))
chis = np.zeros(( len(ns), len(betas), bs))

for i, n in enumerate(ns):
    for j, b in enumerate(betas):
        path =  f"../../../../project_data/newtune/{sitex:g}*{sitey:g}U{U:g}/tp{tp:g}beta{b:g}/n{n:g}/"
        saving(U,tp,b,n,i,j,sitex,sitey,bs,w,dw,jeje,jkjk,jpjp,
               j0j0,C,chi,jejes,jkjks,jpjps,j0j0s,Cs,chis,prefix,mdls=mdls,path=path,modelstyle='annealing_single',alwaysBT=True)
# Out:
# ../../../../project_data/newtune/4*4U8/tp0beta2/n1/
# 250000.0
# 800/800 complete bins
# nbin=800	<sign>=1.0
# 200000000.0 total samples
# jeje
# alpha=11220.185	chi2/dof=2.439	A.sum()=0.999596
# jkjk
# alpha=1122.018	chi2/dof=2.057	A.sum()=1.000536
# jpjp
# alpha=2818.383	chi2/dof=1.541	A.sum()=1.000043
# j0j0
# alpha=50118.723	chi2/dof=6.950	A.sum()=0.999859
# 250000.0
# 800/800 complete bins
# nbin=800	<sign>=1.0
# 200000000.0 total samples
# jeje
# alpha=11220.185	chi2/dof=2.732	A.sum()=0.999799
# alpha=7943.282	chi2/dof=1.585	A.sum()=0.999737
# alpha=3162.278	chi2/dof=2.143	A.sum()=0.999924
# alpha=17782.794	chi2/dof=4.253	A.sum()=0.999446
# alpha=14125.375	chi2/dof=3.989	A.sum()=0.999928
# alpha=12589.254	chi2/dof=2.714	A.sum()=0.999624
# alpha=14125.375	chi2/dof=3.132	A.sum()=0.999731
# alpha=14125.375	chi2/dof=4.954	A.sum()=0.999214
# alpha=14125.375	chi2/dof=3.381	A.sum()=0.999502
# alpha=3548.134	chi2/dof=2.656	A.sum()=0.999336
# alpha=2818.383	chi2/dof=1.911	A.sum()=0.999611
# alpha=14125.375	chi2/dof=3.579	A.sum()=0.999420
# alpha=15848.932	chi2/dof=3.843	A.sum()=0.999760
# alpha=10000.000	chi2/dof=2.652	A.sum()=1.000013
# alpha=12589.254	chi2/dof=3.693	A.sum()=0.999030
# alpha=12589.254	chi2/dof=3.406	A.sum()=0.999690
# alpha=10000.000	chi2/dof=2.721	A.sum()=0.999179
# alpha=3548.134	chi2/dof=1.935	A.sum()=0.999602
# alpha=14125.375	chi2/dof=4.386	A.sum()=0.999698
# alpha=17782.794	chi2/dof=4.427	A.sum()=0.999586
# alpha=14125.375	chi2/dof=3.464	A.sum()=0.999497
# alpha=14125.375	chi2/dof=3.502	A.sum()=0.999393
# alpha=14125.375	chi2/dof=3.086	A.sum()=0.999590
# alpha=11220.185	chi2/dof=3.535	A.sum()=0.999664
# alpha=11220.185	chi2/dof=2.986	A.sum()=0.999824
# alpha=14125.375	chi2/dof=3.436	A.sum()=0.999293
# alpha=19952.623	chi2/dof=4.726	A.sum()=0.999153
# alpha=11220.185	chi2/dof=2.891	A.sum()=0.999403
# alpha=12589.254	chi2/dof=3.831	A.sum()=0.999461
# alpha=12589.254	chi2/dof=3.677	A.sum()=0.999330
# alpha=17782.794	chi2/dof=4.057	A.sum()=0.999468
# alpha=12589.254	chi2/dof=3.320	A.sum()=0.999935
# alpha=12589.254	chi2/dof=3.160	A.sum()=0.999971
# alpha=17782.794	chi2/dof=4.529	A.sum()=0.999036
# alpha=14125.375	chi2/dof=3.806	A.sum()=0.999054
# alpha=12589.254	chi2/dof=2.672	A.sum()=0.999886
# alpha=11220.185	chi2/dof=2.773	A.sum()=0.999326
# alpha=15848.932	chi2/dof=4.130	A.sum()=0.999776
# alpha=17782.794	chi2/dof=5.194	A.sum()=0.999062
# alpha=2818.383	chi2/dof=1.484	A.sum()=0.999932
# alpha=12589.254	chi2/dof=3.500	A.sum()=0.999433
# alpha=12589.254	chi2/dof=3.548	A.sum()=0.998881
# alpha=25118.864	chi2/dof=6.435	A.sum()=0.999275
# alpha=12589.254	chi2/dof=2.864	A.sum()=0.999553
# alpha=12589.254	chi2/dof=3.465	A.sum()=0.999873
# alpha=15848.932	chi2/dof=4.121	A.sum()=0.999227
# alpha=14125.375	chi2/dof=3.115	A.sum()=0.999429
# alpha=19952.623	chi2/dof=4.555	A.sum()=0.999332
# alpha=17782.794	chi2/dof=4.241	A.sum()=0.999323
# alpha=14125.375	chi2/dof=3.458	A.sum()=0.999466
# alpha=11220.185	chi2/dof=2.890	A.sum()=0.999803
# alpha=11220.185	chi2/dof=2.509	A.sum()=0.999940
# alpha=11220.185	chi2/dof=2.426	A.sum()=0.999551
# alpha=12589.254	chi2/dof=3.500	A.sum()=0.999360
# alpha=14125.375	chi2/dof=3.244	A.sum()=0.999676
# alpha=14125.375	chi2/dof=3.242	A.sum()=0.999245
# alpha=12589.254	chi2/dof=4.421	A.sum()=0.999207
# alpha=14125.375	chi2/dof=3.464	A.sum()=0.999501
# alpha=5623.413	chi2/dof=1.108	A.sum()=0.999438
# alpha=14125.375	chi2/dof=3.573	A.sum()=0.999741
# alpha=15848.932	chi2/dof=3.393	A.sum()=0.999698
# alpha=7943.282	chi2/dof=1.811	A.sum()=0.999354
# alpha=2818.383	chi2/dof=1.544	A.sum()=1.000035
# alpha=8912.509	chi2/dof=1.569	A.sum()=0.999954
# alpha=14125.375	chi2/dof=3.052	A.sum()=0.999456
# alpha=10000.000	chi2/dof=2.225	A.sum()=0.999351
# alpha=14125.375	chi2/dof=2.474	A.sum()=0.999627
# alpha=12589.254	chi2/dof=3.301	A.sum()=0.999185
# alpha=14125.375	chi2/dof=3.176	A.sum()=0.999787
# alpha=3162.278	chi2/dof=1.577	A.sum()=0.999643
# alpha=14125.375	chi2/dof=4.181	A.sum()=0.999455
# alpha=17782.794	chi2/dof=4.240	A.sum()=0.999402
# alpha=17782.794	chi2/dof=5.650	A.sum()=0.999155
# alpha=14125.375	chi2/dof=4.566	A.sum()=0.999627
# alpha=17782.794	chi2/dof=4.702	A.sum()=0.999335
# alpha=12589.254	chi2/dof=3.436	A.sum()=0.999391
# alpha=17782.794	chi2/dof=4.958	A.sum()=0.998673
# alpha=11220.185	chi2/dof=3.141	A.sum()=0.999399
# alpha=3981.072	chi2/dof=1.571	A.sum()=0.999951
# alpha=14125.375	chi2/dof=4.314	A.sum()=0.999213
# alpha=12589.254	chi2/dof=2.722	A.sum()=0.999427
# alpha=10000.000	chi2/dof=2.066	A.sum()=1.000135
# alpha=11220.185	chi2/dof=3.076	A.sum()=0.999657
# alpha=15848.932	chi2/dof=4.400	A.sum()=0.999742
# alpha=17782.794	chi2/dof=5.766	A.sum()=0.999869
# alpha=17782.794	chi2/dof=5.059	A.sum()=0.999235
# alpha=14125.375	chi2/dof=3.058	A.sum()=0.999881
# alpha=12589.254	chi2/dof=3.485	A.sum()=0.999659
# alpha=12589.254	chi2/dof=3.304	A.sum()=0.999705
# alpha=28183.829	chi2/dof=7.212	A.sum()=0.999167
# alpha=15848.932	chi2/dof=4.989	A.sum()=0.999479
# alpha=12589.254	chi2/dof=3.281	A.sum()=0.999487
# alpha=14125.375	chi2/dof=3.641	A.sum()=0.999607
# alpha=15848.932	chi2/dof=4.305	A.sum()=0.998914
# alpha=12589.254	chi2/dof=3.655	A.sum()=0.999454
# alpha=12589.254	chi2/dof=3.441	A.sum()=0.999629
# alpha=15848.932	chi2/dof=3.730	A.sum()=0.999200
# alpha=2238.721	chi2/dof=1.167	A.sum()=0.999756
# alpha=12589.254	chi2/dof=3.123	A.sum()=0.999382
# alpha=3548.134	chi2/dof=2.071	A.sum()=0.999541
# alpha=17782.794	chi2/dof=4.754	A.sum()=0.999165
# alpha=11220.185	chi2/dof=2.721	A.sum()=0.999515
# alpha=14125.375	chi2/dof=3.475	A.sum()=0.999807
# alpha=19952.623	chi2/dof=4.621	A.sum()=0.999794
# alpha=10000.000	chi2/dof=2.699	A.sum()=0.999590
# alpha=4466.836	chi2/dof=2.170	A.sum()=0.999725
# alpha=12589.254	chi2/dof=3.332	A.sum()=0.999549
# alpha=11220.185	chi2/dof=2.903	A.sum()=0.999393
# alpha=10000.000	chi2/dof=2.440	A.sum()=0.999848
# alpha=17782.794	chi2/dof=4.163	A.sum()=0.999896
# alpha=15848.932	chi2/dof=5.164	A.sum()=0.999233
# alpha=11220.185	chi2/dof=2.745	A.sum()=0.999514
# alpha=14125.375	chi2/dof=3.540	A.sum()=0.999453
# alpha=12589.254	chi2/dof=2.806	A.sum()=0.999920
# alpha=8912.509	chi2/dof=1.893	A.sum()=0.999855
# alpha=14125.375	chi2/dof=3.609	A.sum()=0.998861
# alpha=3162.278	chi2/dof=2.126	A.sum()=0.999317
# alpha=3162.278	chi2/dof=2.053	A.sum()=0.999729
# alpha=3548.134	chi2/dof=2.079	A.sum()=0.999258
# alpha=22387.211	chi2/dof=5.816	A.sum()=0.999117
# alpha=14125.375	chi2/dof=3.250	A.sum()=0.999573
# alpha=14125.375	chi2/dof=3.570	A.sum()=0.999442
# alpha=12589.254	chi2/dof=3.465	A.sum()=0.999281
# alpha=8912.509	chi2/dof=2.016	A.sum()=0.999203
# alpha=19952.623	chi2/dof=5.327	A.sum()=0.999353
# alpha=15848.932	chi2/dof=3.859	A.sum()=0.999549
# alpha=19952.623	chi2/dof=6.337	A.sum()=0.999621
# alpha=17782.794	chi2/dof=5.152	A.sum()=0.999848
# alpha=12589.254	chi2/dof=3.795	A.sum()=0.999485
# alpha=14125.375	chi2/dof=3.053	A.sum()=0.999596
# alpha=11220.185	chi2/dof=2.924	A.sum()=0.999557
# alpha=14125.375	chi2/dof=3.129	A.sum()=0.999563
# alpha=14125.375	chi2/dof=3.901	A.sum()=0.999394
# alpha=3548.134	chi2/dof=1.873	A.sum()=0.999738
# alpha=3548.134	chi2/dof=1.839	A.sum()=0.999702
# alpha=15848.932	chi2/dof=4.349	A.sum()=0.999482
# alpha=10000.000	chi2/dof=2.210	A.sum()=0.999887
# alpha=17782.794	chi2/dof=4.195	A.sum()=0.999446
# alpha=8912.509	chi2/dof=2.191	A.sum()=1.000023
# alpha=11220.185	chi2/dof=2.625	A.sum()=1.000034
# alpha=14125.375	chi2/dof=3.675	A.sum()=1.000003
# alpha=15848.932	chi2/dof=4.698	A.sum()=0.999233
# alpha=14125.375	chi2/dof=3.851	A.sum()=0.999543
# alpha=14125.375	chi2/dof=2.728	A.sum()=0.999899
# alpha=14125.375	chi2/dof=3.737	A.sum()=0.999441
# alpha=17782.794	chi2/dof=5.082	A.sum()=0.999578
# alpha=22387.211	chi2/dof=6.242	A.sum()=0.999196
# alpha=12589.254	chi2/dof=2.937	A.sum()=0.999460
# alpha=12589.254	chi2/dof=2.819	A.sum()=0.999875
# alpha=11220.185	chi2/dof=3.376	A.sum()=0.999777
# alpha=11220.185	chi2/dof=2.744	A.sum()=0.999597
# alpha=12589.254	chi2/dof=2.948	A.sum()=0.999616
# alpha=15848.932	chi2/dof=4.896	A.sum()=0.999351
# alpha=10000.000	chi2/dof=2.624	A.sum()=0.999561
# alpha=14125.375	chi2/dof=2.737	A.sum()=0.999434
# alpha=19952.623	chi2/dof=5.111	A.sum()=0.999174
# alpha=12589.254	chi2/dof=3.695	A.sum()=0.998931
# alpha=12589.254	chi2/dof=3.432	A.sum()=0.999844
# alpha=2818.383	chi2/dof=1.232	A.sum()=0.999592
# alpha=3981.072	chi2/dof=2.096	A.sum()=0.999334
# alpha=12589.254	chi2/dof=3.564	A.sum()=1.000005
# alpha=14125.375	chi2/dof=3.743	A.sum()=0.999664
# alpha=14125.375	chi2/dof=3.958	A.sum()=0.999641
# alpha=7943.282	chi2/dof=1.481	A.sum()=0.999441
# alpha=14125.375	chi2/dof=3.577	A.sum()=0.999426
# alpha=15848.932	chi2/dof=4.525	A.sum()=0.999616
# alpha=15848.932	chi2/dof=4.220	A.sum()=0.999644
# alpha=14125.375	chi2/dof=3.350	A.sum()=0.999659
# alpha=12589.254	chi2/dof=3.243	A.sum()=0.999812
# alpha=17782.794	chi2/dof=5.204	A.sum()=0.999504
# alpha=14125.375	chi2/dof=3.715	A.sum()=0.999540
# alpha=14125.375	chi2/dof=4.583	A.sum()=0.998761
# alpha=2238.721	chi2/dof=1.198	A.sum()=0.999444
# alpha=11220.185	chi2/dof=2.904	A.sum()=0.999183
# alpha=12589.254	chi2/dof=2.710	A.sum()=0.999663
# alpha=12589.254	chi2/dof=2.987	A.sum()=0.999767
# alpha=11220.185	chi2/dof=2.675	A.sum()=0.999711
# alpha=14125.375	chi2/dof=4.458	A.sum()=0.999427
# alpha=14125.375	chi2/dof=3.394	A.sum()=0.999479
# alpha=8912.509	chi2/dof=1.782	A.sum()=0.999686
# alpha=3548.134	chi2/dof=2.455	A.sum()=0.999693
# alpha=10000.000	chi2/dof=2.363	A.sum()=0.999338
# alpha=15848.932	chi2/dof=4.312	A.sum()=0.999398
# alpha=11220.185	chi2/dof=2.668	A.sum()=0.999838
# alpha=17782.794	chi2/dof=4.980	A.sum()=0.999255
# alpha=17782.794	chi2/dof=4.338	A.sum()=0.999543
# alpha=15848.932	chi2/dof=3.672	A.sum()=0.999469
# alpha=15848.932	chi2/dof=3.638	A.sum()=0.999876
# alpha=14125.375	chi2/dof=3.636	A.sum()=0.999426
# alpha=3981.072	chi2/dof=2.019	A.sum()=0.999700
# alpha=11220.185	chi2/dof=2.540	A.sum()=0.999793
# alpha=15848.932	chi2/dof=4.516	A.sum()=0.998879
# alpha=2818.383	chi2/dof=1.953	A.sum()=0.999858
# alpha=8912.509	chi2/dof=2.297	A.sum()=0.999868
# alpha=17782.794	chi2/dof=4.143	A.sum()=0.999607
# alpha=5011.872	chi2/dof=3.114	A.sum()=0.999736
# alpha=8912.509	chi2/dof=2.143	A.sum()=0.999905
# alpha=12589.254	chi2/dof=3.442	A.sum()=0.999600
# alpha=10000.000	chi2/dof=2.047	A.sum()=0.999933
# alpha=2818.383	chi2/dof=1.692	A.sum()=0.999494
# jkjk
# alpha=1122.018	chi2/dof=2.162	A.sum()=1.000882
# alpha=17782.794	chi2/dof=8.896	A.sum()=1.001397
# alpha=1584.893	chi2/dof=3.313	A.sum()=1.000522
# alpha=2238.721	chi2/dof=5.253	A.sum()=1.000513
# alpha=1258.925	chi2/dof=2.503	A.sum()=1.001030
# alpha=1584.893	chi2/dof=2.285	A.sum()=1.000303
# alpha=1258.925	chi2/dof=2.956	A.sum()=1.000888
# alpha=1258.925	chi2/dof=3.132	A.sum()=1.000736
# alpha=1122.018	chi2/dof=3.260	A.sum()=1.000976
# alpha=1412.538	chi2/dof=3.567	A.sum()=1.000987
# alpha=1412.538	chi2/dof=2.260	A.sum()=1.000414
# alpha=1584.893	chi2/dof=2.965	A.sum()=1.000511
# alpha=1995.262	chi2/dof=3.599	A.sum()=1.000224
# alpha=1584.893	chi2/dof=3.140	A.sum()=1.000250
# alpha=2238721.139	chi2/dof=106.893	A.sum()=1.006673
# alpha=1995262.315	chi2/dof=89.076	A.sum()=1.008377
# alpha=1258.925	chi2/dof=2.014	A.sum()=1.000353
# alpha=1412.538	chi2/dof=2.551	A.sum()=1.000419
# alpha=22387.211	chi2/dof=10.415	A.sum()=1.002327
# alpha=1778.279	chi2/dof=3.981	A.sum()=1.000403
# alpha=22387.211	chi2/dof=8.897	A.sum()=1.001692
# alpha=1584.893	chi2/dof=3.115	A.sum()=1.000335
# alpha=22387.211	chi2/dof=10.525	A.sum()=1.002217
# alpha=1122.018	chi2/dof=2.550	A.sum()=1.000811
# alpha=1258.925	chi2/dof=2.436	A.sum()=1.000689
# alpha=2238721.139	chi2/dof=108.170	A.sum()=1.005066
# alpha=1258.925	chi2/dof=3.299	A.sum()=1.001178
# alpha=891.251	chi2/dof=1.254	A.sum()=1.000471
# alpha=1995262.315	chi2/dof=99.121	A.sum()=1.008531
# alpha=1258.925	chi2/dof=3.174	A.sum()=1.000934
# alpha=1258.925	chi2/dof=3.557	A.sum()=1.001236
# alpha=1412.538	chi2/dof=2.167	A.sum()=1.000155
# alpha=1778279.410	chi2/dof=79.954	A.sum()=1.008848
# alpha=1995.262	chi2/dof=3.795	A.sum()=1.000154
# alpha=2238721.139	chi2/dof=100.927	A.sum()=1.009284
# alpha=1412.538	chi2/dof=2.455	A.sum()=1.000485
# alpha=19952.623	chi2/dof=9.614	A.sum()=1.002129
# alpha=891.251	chi2/dof=2.012	A.sum()=1.001260
# alpha=1995.262	chi2/dof=3.168	A.sum()=1.000168
# alpha=1122.018	chi2/dof=2.384	A.sum()=1.000763
# alpha=1258.925	chi2/dof=2.926	A.sum()=1.000607
# alpha=1778279.410	chi2/dof=91.101	A.sum()=1.004219
# alpha=1122.018	chi2/dof=2.065	A.sum()=1.000409
# alpha=1584.893	chi2/dof=2.379	A.sum()=1.000248
# alpha=1584.893	chi2/dof=2.839	A.sum()=1.000426
# alpha=1584.893	chi2/dof=4.272	A.sum()=1.000947
# alpha=1995262.315	chi2/dof=97.067	A.sum()=1.008964
# alpha=25118.864	chi2/dof=10.089	A.sum()=1.001478
# alpha=1258.925	chi2/dof=4.106	A.sum()=1.000825
# alpha=1412.538	chi2/dof=3.384	A.sum()=1.001663
# alpha=14125.375	chi2/dof=6.687	A.sum()=1.001817
# alpha=1584.893	chi2/dof=2.673	A.sum()=1.000308
# alpha=1258.925	chi2/dof=2.885	A.sum()=1.000687
# alpha=17782.794	chi2/dof=10.325	A.sum()=1.002258
# alpha=1995.262	chi2/dof=3.624	A.sum()=1.000411
# alpha=2238721.139	chi2/dof=101.731	A.sum()=1.006951
# alpha=1995262.315	chi2/dof=91.592	A.sum()=1.008545
# alpha=1122.018	chi2/dof=2.425	A.sum()=1.001004
# alpha=17782.794	chi2/dof=9.498	A.sum()=1.002179
# alpha=1995262.315	chi2/dof=91.904	A.sum()=1.008379
# alpha=1122.018	chi2/dof=3.197	A.sum()=1.000727
# alpha=1122.018	chi2/dof=2.376	A.sum()=1.000390
# alpha=1258.925	chi2/dof=2.545	A.sum()=1.000413
# alpha=1258.925	chi2/dof=2.694	A.sum()=1.000284
# alpha=1412.538	chi2/dof=2.320	A.sum()=0.999903
# alpha=1584.893	chi2/dof=3.181	A.sum()=1.000739
# alpha=2238721.139	chi2/dof=101.711	A.sum()=1.006930
# alpha=1122.018	chi2/dof=2.799	A.sum()=1.001132
# alpha=1412.538	chi2/dof=2.666	A.sum()=1.000339
# alpha=2238721.139	chi2/dof=101.602	A.sum()=1.005048
# alpha=1258.925	chi2/dof=3.182	A.sum()=1.000731
# alpha=1995262.315	chi2/dof=95.456	A.sum()=1.008559
# alpha=1412.538	chi2/dof=3.761	A.sum()=1.000552
# alpha=1000.000	chi2/dof=2.111	A.sum()=1.000724
# alpha=1000.000	chi2/dof=2.202	A.sum()=1.001086
# alpha=1584.893	chi2/dof=3.252	A.sum()=1.000384
# alpha=1258.925	chi2/dof=2.016	A.sum()=1.000244
# alpha=2238721.139	chi2/dof=97.500	A.sum()=1.010412
# alpha=1995262.315	chi2/dof=100.625	A.sum()=1.007794
# alpha=1412.538	chi2/dof=2.829	A.sum()=1.000417
# alpha=1412.538	chi2/dof=3.348	A.sum()=1.000345
# alpha=1122.018	chi2/dof=2.112	A.sum()=1.000274
# alpha=17782.794	chi2/dof=6.700	A.sum()=1.001434
# alpha=1995.262	chi2/dof=3.700	A.sum()=1.000449
# alpha=1584.893	chi2/dof=2.759	A.sum()=1.000494
# alpha=22387.211	chi2/dof=10.969	A.sum()=1.001837
# alpha=1995262.315	chi2/dof=105.459	A.sum()=1.005143
# alpha=1778.279	chi2/dof=2.979	A.sum()=1.000434
# alpha=1412.538	chi2/dof=2.534	A.sum()=1.000277
# alpha=1778.279	chi2/dof=3.179	A.sum()=1.000267
# alpha=1412.538	chi2/dof=3.352	A.sum()=1.000877
# alpha=19952.623	chi2/dof=10.066	A.sum()=1.001468
# alpha=19952.623	chi2/dof=8.402	A.sum()=1.002662
# alpha=1122.018	chi2/dof=2.714	A.sum()=1.001028
# alpha=1995262.315	chi2/dof=96.723	A.sum()=1.009098
# alpha=1412.538	chi2/dof=3.507	A.sum()=1.000971
# alpha=1778.279	chi2/dof=3.506	A.sum()=1.000301
# alpha=1778279.410	chi2/dof=81.707	A.sum()=1.007925
# alpha=1412.538	chi2/dof=2.360	A.sum()=1.000921
# alpha=1122.018	chi2/dof=2.768	A.sum()=1.001153
# alpha=22387.211	chi2/dof=10.151	A.sum()=1.002134
# alpha=1412.538	chi2/dof=3.337	A.sum()=1.000923
# alpha=1778279.410	chi2/dof=93.754	A.sum()=1.006397
# alpha=1000.000	chi2/dof=2.005	A.sum()=1.000817
# alpha=891.251	chi2/dof=1.704	A.sum()=1.000694
# alpha=1995.262	chi2/dof=3.776	A.sum()=1.000425
# alpha=1995262.315	chi2/dof=90.368	A.sum()=1.007864
# alpha=1258.925	chi2/dof=2.636	A.sum()=1.000979
# alpha=1000.000	chi2/dof=1.653	A.sum()=1.000803
# alpha=1584893.192	chi2/dof=94.913	A.sum()=1.004909
# alpha=1258.925	chi2/dof=2.666	A.sum()=1.000638
# alpha=1122.018	chi2/dof=2.423	A.sum()=1.000682
# alpha=1412.538	chi2/dof=2.767	A.sum()=1.000664
# alpha=19952.623	chi2/dof=9.164	A.sum()=1.001406
# alpha=1584.893	chi2/dof=2.969	A.sum()=1.000337
# alpha=1122.018	chi2/dof=3.317	A.sum()=1.001249
# alpha=1122.018	chi2/dof=2.996	A.sum()=1.001011
# alpha=1778.279	chi2/dof=4.222	A.sum()=1.000368
# alpha=1412.538	chi2/dof=2.989	A.sum()=1.000674
# alpha=1258.925	chi2/dof=3.496	A.sum()=1.001292
# alpha=1995262.315	chi2/dof=101.714	A.sum()=1.008153
# alpha=1122.018	chi2/dof=1.894	A.sum()=1.000664
# alpha=1000.000	chi2/dof=2.121	A.sum()=1.000725
# alpha=1258.925	chi2/dof=2.483	A.sum()=1.000518
# alpha=1000.000	chi2/dof=2.326	A.sum()=1.000826
# alpha=1000.000	chi2/dof=2.348	A.sum()=1.001136
# alpha=1000.000	chi2/dof=2.563	A.sum()=1.000460
# alpha=1995262.315	chi2/dof=90.949	A.sum()=1.006802
# alpha=1584.893	chi2/dof=3.175	A.sum()=1.000408
# alpha=1584.893	chi2/dof=2.882	A.sum()=1.000079
# alpha=1995262.315	chi2/dof=88.944	A.sum()=1.007581
# alpha=1584.893	chi2/dof=3.429	A.sum()=1.000518
# alpha=2238.721	chi2/dof=4.172	A.sum()=1.000218
# alpha=1258.925	chi2/dof=2.212	A.sum()=1.000998
# alpha=1995.262	chi2/dof=3.708	A.sum()=1.000608
# alpha=19952.623	chi2/dof=8.505	A.sum()=1.001524
# alpha=1412.538	chi2/dof=2.530	A.sum()=1.000604
# alpha=1122.018	chi2/dof=3.888	A.sum()=1.001348
# alpha=1584.893	chi2/dof=2.530	A.sum()=1.000289
# alpha=1258.925	chi2/dof=3.369	A.sum()=1.000824
# alpha=1778.279	chi2/dof=4.258	A.sum()=1.000429
# alpha=22387.211	chi2/dof=11.753	A.sum()=1.003920
# alpha=1584.893	chi2/dof=3.586	A.sum()=1.000443
# alpha=1584.893	chi2/dof=3.364	A.sum()=1.000172
# alpha=1778279.410	chi2/dof=92.409	A.sum()=1.006440
# alpha=1258.925	chi2/dof=2.790	A.sum()=1.000585
# alpha=1122.018	chi2/dof=2.005	A.sum()=1.000644
# alpha=2238721.139	chi2/dof=115.849	A.sum()=1.004929
# alpha=1584.893	chi2/dof=3.583	A.sum()=1.000490
# alpha=14125.375	chi2/dof=7.097	A.sum()=1.002727
# alpha=1584.893	chi2/dof=3.266	A.sum()=1.000283
# alpha=1584.893	chi2/dof=2.963	A.sum()=1.000461
# alpha=1584893.192	chi2/dof=96.938	A.sum()=1.005017
# alpha=1995262.315	chi2/dof=87.548	A.sum()=1.010549
# alpha=1584.893	chi2/dof=2.495	A.sum()=1.000466
# alpha=1122.018	chi2/dof=2.338	A.sum()=1.000767
# alpha=1995262.315	chi2/dof=101.586	A.sum()=1.007400
# alpha=1412.538	chi2/dof=2.797	A.sum()=1.000309
# alpha=1412.538	chi2/dof=2.139	A.sum()=1.000390
# alpha=1412.538	chi2/dof=3.260	A.sum()=1.000905
# alpha=2238721.139	chi2/dof=96.392	A.sum()=1.009760
# alpha=19952.623	chi2/dof=9.685	A.sum()=1.002645
# alpha=1122.018	chi2/dof=3.213	A.sum()=1.000923
# alpha=1258.925	chi2/dof=3.168	A.sum()=1.000597
# alpha=1584.893	chi2/dof=2.917	A.sum()=1.000608
# alpha=1778.279	chi2/dof=2.764	A.sum()=1.000175
# alpha=1584.893	chi2/dof=2.515	A.sum()=1.000123
# alpha=1122.018	chi2/dof=2.561	A.sum()=1.001106
# alpha=1778279.410	chi2/dof=95.760	A.sum()=1.007533
# alpha=1778.279	chi2/dof=3.282	A.sum()=1.000221
# alpha=1995.262	chi2/dof=3.280	A.sum()=1.000360
# alpha=1995262.315	chi2/dof=97.512	A.sum()=1.008236
# alpha=1778.279	chi2/dof=3.792	A.sum()=1.000321
# alpha=1778.279	chi2/dof=2.670	A.sum()=1.000207
# alpha=1412.538	chi2/dof=2.658	A.sum()=1.000424
# alpha=25118.864	chi2/dof=10.537	A.sum()=1.002130
# alpha=15848.932	chi2/dof=8.783	A.sum()=1.002053
# alpha=1412.538	chi2/dof=2.921	A.sum()=1.000818
# alpha=2238721.139	chi2/dof=102.751	A.sum()=1.009816
# alpha=1778.279	chi2/dof=2.959	A.sum()=1.000210
# alpha=1412.538	chi2/dof=2.865	A.sum()=1.001130
# alpha=1995.262	chi2/dof=3.819	A.sum()=1.000382
# alpha=1778279.410	chi2/dof=85.476	A.sum()=1.007463
# alpha=17782.794	chi2/dof=8.231	A.sum()=1.002230
# alpha=1258.925	chi2/dof=2.665	A.sum()=1.001084
# alpha=1995262.315	chi2/dof=100.026	A.sum()=1.006958
# alpha=2238.721	chi2/dof=4.347	A.sum()=0.999964
# alpha=1778.279	chi2/dof=2.956	A.sum()=1.000062
# alpha=1412.538	chi2/dof=3.310	A.sum()=1.000263
# alpha=1412.538	chi2/dof=2.730	A.sum()=1.000624
# alpha=1122.018	chi2/dof=3.093	A.sum()=1.000659
# alpha=19952.623	chi2/dof=10.365	A.sum()=1.001795
# alpha=1584.893	chi2/dof=4.271	A.sum()=1.000165
# alpha=1995262.315	chi2/dof=102.784	A.sum()=1.006341
# alpha=1122.018	chi2/dof=2.926	A.sum()=1.001366
# alpha=1412.538	chi2/dof=3.299	A.sum()=1.000746
# alpha=1000.000	chi2/dof=1.870	A.sum()=1.000757
# alpha=1258.925	chi2/dof=2.358	A.sum()=1.000770
# alpha=1995262.315	chi2/dof=99.549	A.sum()=1.005364
# alpha=1258.925	chi2/dof=3.502	A.sum()=1.000855
# jpjp
# alpha=35481.339	chi2/dof=9.621	A.sum()=0.999632
# alpha=25118.864	chi2/dof=6.198	A.sum()=1.000229
# alpha=3548.134	chi2/dof=2.314	A.sum()=1.000133
# alpha=31622.777	chi2/dof=8.943	A.sum()=0.999800
# alpha=3981.072	chi2/dof=2.468	A.sum()=1.000044
# alpha=22387.211	chi2/dof=5.443	A.sum()=0.999807
# alpha=3548.134	chi2/dof=2.194	A.sum()=0.999972
# alpha=2238.721	chi2/dof=1.051	A.sum()=0.999991
# alpha=31622.777	chi2/dof=6.475	A.sum()=1.000192
# alpha=3548.134	chi2/dof=2.439	A.sum()=0.999776
# alpha=3548.134	chi2/dof=2.495	A.sum()=1.000001
# alpha=3548.134	chi2/dof=1.838	A.sum()=1.000214
# alpha=3981.072	chi2/dof=2.155	A.sum()=1.000076
# alpha=3981.072	chi2/dof=3.005	A.sum()=1.000039
# alpha=22387.211	chi2/dof=6.073	A.sum()=0.999882
# alpha=3162.278	chi2/dof=2.343	A.sum()=0.999964
# alpha=17782.794	chi2/dof=4.223	A.sum()=1.000239
# alpha=4466.836	chi2/dof=2.706	A.sum()=0.999795
# alpha=5011.872	chi2/dof=2.846	A.sum()=0.999979
# alpha=3548.134	chi2/dof=2.128	A.sum()=1.000089
# alpha=3548.134	chi2/dof=2.213	A.sum()=0.999633
# alpha=3548.134	chi2/dof=3.024	A.sum()=1.000027
# alpha=25118.864	chi2/dof=6.514	A.sum()=0.999711
# alpha=4466.836	chi2/dof=2.440	A.sum()=0.999918
# alpha=3548.134	chi2/dof=1.673	A.sum()=0.999904
# alpha=31622.777	chi2/dof=7.199	A.sum()=0.999880
# alpha=3548.134	chi2/dof=4.002	A.sum()=0.999543
# alpha=3981.072	chi2/dof=1.476	A.sum()=1.000236
# alpha=3162.278	chi2/dof=2.217	A.sum()=1.000136
# alpha=22387.211	chi2/dof=5.746	A.sum()=1.000306
# alpha=3981.072	chi2/dof=1.870	A.sum()=1.000072
# alpha=3981.072	chi2/dof=2.147	A.sum()=1.000143
# alpha=3981.072	chi2/dof=1.875	A.sum()=1.000025
# alpha=3548.134	chi2/dof=2.310	A.sum()=1.000004
# alpha=3162.278	chi2/dof=1.585	A.sum()=1.000122
# alpha=25118.864	chi2/dof=7.189	A.sum()=0.999817
# alpha=4466.836	chi2/dof=2.112	A.sum()=0.999659
# alpha=3162.278	chi2/dof=1.666	A.sum()=1.000054
# alpha=28183.829	chi2/dof=7.214	A.sum()=0.999367
# alpha=3981.072	chi2/dof=2.817	A.sum()=0.999525
# alpha=3981.072	chi2/dof=3.860	A.sum()=0.999492
# alpha=31622.777	chi2/dof=7.008	A.sum()=1.000098
# alpha=3548.134	chi2/dof=1.922	A.sum()=0.999792
# alpha=3548.134	chi2/dof=1.546	A.sum()=0.999991
# alpha=3548.134	chi2/dof=2.172	A.sum()=1.000076
# alpha=3981.072	chi2/dof=2.891	A.sum()=1.000323
# alpha=3548.134	chi2/dof=2.151	A.sum()=1.000001
# alpha=31622.777	chi2/dof=7.939	A.sum()=0.999745
# alpha=22387.211	chi2/dof=5.081	A.sum()=1.000034
# alpha=25118.864	chi2/dof=7.023	A.sum()=0.999323
# alpha=28183.829	chi2/dof=6.968	A.sum()=0.999711
# alpha=31622.777	chi2/dof=7.100	A.sum()=0.999633
# alpha=3981.072	chi2/dof=1.735	A.sum()=0.999674
# alpha=3548.134	chi2/dof=2.184	A.sum()=0.999926
# alpha=3548.134	chi2/dof=1.824	A.sum()=0.999912
# alpha=3548.134	chi2/dof=2.656	A.sum()=1.000109
# alpha=3548.134	chi2/dof=1.947	A.sum()=1.000297
# alpha=25118.864	chi2/dof=5.824	A.sum()=0.999827
# alpha=3548.134	chi2/dof=1.657	A.sum()=1.000124
# alpha=19952.623	chi2/dof=4.669	A.sum()=0.999744
# alpha=3548.134	chi2/dof=2.579	A.sum()=0.999775
# alpha=22387.211	chi2/dof=5.097	A.sum()=0.999602
# alpha=3162.278	chi2/dof=2.285	A.sum()=0.999866
# alpha=4466.836	chi2/dof=1.859	A.sum()=1.000100
# alpha=17782.794	chi2/dof=4.243	A.sum()=1.000063
# alpha=3162.278	chi2/dof=1.712	A.sum()=1.000177
# alpha=22387.211	chi2/dof=5.287	A.sum()=0.999475
# alpha=3548.134	chi2/dof=1.843	A.sum()=1.000165
# alpha=3981.072	chi2/dof=2.324	A.sum()=0.999966
# alpha=3981.072	chi2/dof=2.068	A.sum()=1.000051
# alpha=3548.134	chi2/dof=1.920	A.sum()=0.999970
# alpha=4466.836	chi2/dof=2.952	A.sum()=1.000031
# alpha=25118.864	chi2/dof=5.740	A.sum()=0.999868
# alpha=31622.777	chi2/dof=8.358	A.sum()=0.999717
# alpha=3548.134	chi2/dof=2.343	A.sum()=1.000066
# alpha=22387.211	chi2/dof=6.253	A.sum()=0.999821
# alpha=3162.278	chi2/dof=2.208	A.sum()=1.000361
# alpha=3162.278	chi2/dof=2.258	A.sum()=0.999502
# alpha=4466.836	chi2/dof=2.656	A.sum()=0.999829
# alpha=3162.278	chi2/dof=2.025	A.sum()=1.000087
# alpha=2818.383	chi2/dof=1.330	A.sum()=0.999983
# alpha=3162.278	chi2/dof=1.828	A.sum()=0.999930
# alpha=25118.864	chi2/dof=5.274	A.sum()=0.999688
# alpha=3162.278	chi2/dof=2.775	A.sum()=0.999885
# alpha=3162.278	chi2/dof=1.937	A.sum()=0.999916
# alpha=5011.872	chi2/dof=3.063	A.sum()=0.999890
# alpha=3162.278	chi2/dof=1.642	A.sum()=0.999560
# alpha=3981.072	chi2/dof=1.949	A.sum()=0.999658
# alpha=3162.278	chi2/dof=1.912	A.sum()=1.000099
# alpha=22387.211	chi2/dof=6.028	A.sum()=0.999270
# alpha=4466.836	chi2/dof=3.422	A.sum()=0.999997
# alpha=2818.383	chi2/dof=2.066	A.sum()=0.999632
# alpha=3981.072	chi2/dof=2.916	A.sum()=0.999903
# alpha=3981.072	chi2/dof=2.483	A.sum()=0.999835
# alpha=3162.278	chi2/dof=2.415	A.sum()=1.000022
# alpha=3162.278	chi2/dof=2.338	A.sum()=0.999959
# alpha=3162.278	chi2/dof=1.827	A.sum()=1.000055
# alpha=5011.872	chi2/dof=3.782	A.sum()=0.999872
# alpha=3981.072	chi2/dof=2.787	A.sum()=0.999390
# alpha=3548.134	chi2/dof=2.171	A.sum()=0.999525
# alpha=31622.777	chi2/dof=6.755	A.sum()=0.999939
# alpha=3162.278	chi2/dof=1.680	A.sum()=1.000125
# alpha=22387.211	chi2/dof=5.375	A.sum()=0.999653
# alpha=3162.278	chi2/dof=1.798	A.sum()=0.999916
# alpha=3548.134	chi2/dof=1.901	A.sum()=1.000096
# alpha=3162.278	chi2/dof=2.407	A.sum()=0.999852
# alpha=3162.278	chi2/dof=2.128	A.sum()=1.000078
# alpha=28183.829	chi2/dof=8.076	A.sum()=1.000293
# alpha=3548.134	chi2/dof=2.214	A.sum()=0.999822
# alpha=25118.864	chi2/dof=5.815	A.sum()=0.999928
# alpha=22387.211	chi2/dof=5.658	A.sum()=0.999864
# alpha=25118.864	chi2/dof=6.000	A.sum()=0.999917
# alpha=25118.864	chi2/dof=5.952	A.sum()=1.000034
# alpha=28183.829	chi2/dof=7.788	A.sum()=0.999475
# alpha=6309.573	chi2/dof=3.808	A.sum()=1.000005
# alpha=4466.836	chi2/dof=3.029	A.sum()=1.000136
# alpha=3162.278	chi2/dof=2.403	A.sum()=0.999837
# alpha=3981.072	chi2/dof=2.249	A.sum()=0.999598
# alpha=3162.278	chi2/dof=2.569	A.sum()=0.999723
# alpha=3548.134	chi2/dof=3.270	A.sum()=0.999706
# alpha=22387.211	chi2/dof=5.831	A.sum()=0.999488
# alpha=22387.211	chi2/dof=5.808	A.sum()=0.999763
# alpha=3162.278	chi2/dof=2.954	A.sum()=0.999932
# alpha=4466.836	chi2/dof=2.402	A.sum()=0.999850
# alpha=2818.383	chi2/dof=1.264	A.sum()=0.999935
# alpha=22387.211	chi2/dof=5.504	A.sum()=1.000193
# alpha=28183.829	chi2/dof=7.059	A.sum()=0.999956
# alpha=3162.278	chi2/dof=2.134	A.sum()=0.999930
# alpha=22387.211	chi2/dof=5.883	A.sum()=0.999325
# alpha=4466.836	chi2/dof=2.783	A.sum()=0.999571
# alpha=2511.886	chi2/dof=1.654	A.sum()=0.999927
# alpha=3162.278	chi2/dof=1.682	A.sum()=1.000010
# alpha=17782.794	chi2/dof=4.462	A.sum()=1.000117
# alpha=3548.134	chi2/dof=2.308	A.sum()=0.999725
# alpha=3162.278	chi2/dof=1.615	A.sum()=1.000122
# alpha=4466.836	chi2/dof=2.603	A.sum()=0.999922
# alpha=2818.383	chi2/dof=1.994	A.sum()=0.999895
# alpha=22387.211	chi2/dof=6.572	A.sum()=1.000204
# alpha=25118.864	chi2/dof=6.046	A.sum()=0.999710
# alpha=4466.836	chi2/dof=2.583	A.sum()=1.000028
# alpha=19952.623	chi2/dof=4.466	A.sum()=1.000031
# alpha=15848.932	chi2/dof=4.265	A.sum()=0.999739
# alpha=3162.278	chi2/dof=2.314	A.sum()=1.000204
# alpha=3162.278	chi2/dof=1.650	A.sum()=1.000019
# alpha=19952.623	chi2/dof=4.391	A.sum()=0.999934
# alpha=28183.829	chi2/dof=7.577	A.sum()=0.999415
# alpha=3162.278	chi2/dof=2.317	A.sum()=1.000191
# alpha=10.000	chi2/dof=1.332	A.sum()=0.999666
# alpha=25118.864	chi2/dof=7.007	A.sum()=0.999901
# alpha=3981.072	chi2/dof=2.665	A.sum()=0.999865
# alpha=4466.836	chi2/dof=3.137	A.sum()=1.000022
# alpha=19952.623	chi2/dof=4.713	A.sum()=0.999718
# alpha=22387.211	chi2/dof=5.916	A.sum()=0.999919
# alpha=19952.623	chi2/dof=5.517	A.sum()=0.999683
# alpha=5011.872	chi2/dof=2.920	A.sum()=1.000172
# alpha=3981.072	chi2/dof=2.574	A.sum()=1.000210
# alpha=3162.278	chi2/dof=1.622	A.sum()=1.000209
# alpha=4466.836	chi2/dof=1.703	A.sum()=0.999826
# alpha=3162.278	chi2/dof=1.786	A.sum()=1.000030
# alpha=4466.836	chi2/dof=3.271	A.sum()=0.999674
# alpha=25118.864	chi2/dof=7.005	A.sum()=1.000122
# alpha=3162.278	chi2/dof=1.390	A.sum()=1.000051
# alpha=28183.829	chi2/dof=9.009	A.sum()=0.999368
# alpha=2818.383	chi2/dof=1.306	A.sum()=1.000126
# alpha=3548.134	chi2/dof=2.391	A.sum()=0.999721
# alpha=3548.134	chi2/dof=1.957	A.sum()=1.000183
# alpha=31622.777	chi2/dof=7.777	A.sum()=0.999741
# alpha=3548.134	chi2/dof=2.698	A.sum()=0.999819
# alpha=22387.211	chi2/dof=5.814	A.sum()=0.999656
# alpha=31622.777	chi2/dof=7.102	A.sum()=0.999306
# alpha=3162.278	chi2/dof=2.099	A.sum()=1.000079
# alpha=5011.872	chi2/dof=3.343	A.sum()=0.999722
# alpha=5011.872	chi2/dof=2.561	A.sum()=1.000288
# alpha=3548.134	chi2/dof=2.063	A.sum()=1.000195
# alpha=3548.134	chi2/dof=2.277	A.sum()=0.999870
# alpha=3981.072	chi2/dof=2.294	A.sum()=0.999943
# alpha=3981.072	chi2/dof=2.276	A.sum()=0.999996
# alpha=35481.339	chi2/dof=8.542	A.sum()=0.999761
# alpha=17782.794	chi2/dof=3.941	A.sum()=0.999837
# alpha=2818.383	chi2/dof=1.722	A.sum()=0.999987
# alpha=3548.134	chi2/dof=1.885	A.sum()=0.999870
# alpha=35481.339	chi2/dof=7.940	A.sum()=0.999661
# alpha=31622.777	chi2/dof=7.987	A.sum()=0.999478
# alpha=19952.623	chi2/dof=4.899	A.sum()=1.000153
# alpha=31622.777	chi2/dof=8.093	A.sum()=0.999696
# alpha=31622.777	chi2/dof=6.381	A.sum()=0.999583
# alpha=35481.339	chi2/dof=8.115	A.sum()=0.999834
# alpha=3981.072	chi2/dof=2.359	A.sum()=0.999898
# alpha=35481.339	chi2/dof=9.811	A.sum()=0.999444
# alpha=2818.383	chi2/dof=1.268	A.sum()=0.999745
# alpha=28183.829	chi2/dof=7.173	A.sum()=0.999941
# alpha=2511.886	chi2/dof=1.487	A.sum()=1.000284
# alpha=2818.383	chi2/dof=1.843	A.sum()=1.000053
# alpha=28183.829	chi2/dof=7.333	A.sum()=0.999469
# alpha=3548.134	chi2/dof=2.012	A.sum()=0.999763
# alpha=4466.836	chi2/dof=3.221	A.sum()=1.000126
# alpha=19952.623	chi2/dof=4.523	A.sum()=0.999718
# alpha=3981.072	chi2/dof=2.940	A.sum()=1.000109
# alpha=3548.134	chi2/dof=2.454	A.sum()=0.999839
# alpha=4466.836	chi2/dof=2.344	A.sum()=1.000208
# j0j0
# alpha=100000.000	chi2/dof=16.945	A.sum()=0.999949
# alpha=63095.734	chi2/dof=8.886	A.sum()=0.999656
# alpha=79432.823	chi2/dof=9.450	A.sum()=0.999776
# alpha=63095.734	chi2/dof=8.538	A.sum()=0.999988
# alpha=112201.845	chi2/dof=15.207	A.sum()=0.999758
# alpha=63095.734	chi2/dof=9.191	A.sum()=0.999763
# alpha=63095.734	chi2/dof=11.106	A.sum()=0.999893
# alpha=112201.845	chi2/dof=15.460	A.sum()=0.999941
# alpha=89125.094	chi2/dof=11.219	A.sum()=0.999863
# alpha=70794.578	chi2/dof=11.180	A.sum()=0.999632
# alpha=70794.578	chi2/dof=10.619	A.sum()=0.999674
# alpha=35481.339	chi2/dof=4.932	A.sum()=0.999842
# alpha=70794.578	chi2/dof=10.016	A.sum()=0.999990
# alpha=50118.723	chi2/dof=6.825	A.sum()=0.999901
# alpha=50118.723	chi2/dof=6.933	A.sum()=0.999854
# alpha=70794.578	chi2/dof=9.332	A.sum()=0.999919
# alpha=79432.823	chi2/dof=12.099	A.sum()=0.999717
# alpha=39.811	chi2/dof=0.440	A.sum()=0.999769
# alpha=63095.734	chi2/dof=8.629	A.sum()=0.999880
# alpha=63095.734	chi2/dof=8.651	A.sum()=0.999803
# alpha=63095.734	chi2/dof=9.601	A.sum()=0.999844
# alpha=79432.823	chi2/dof=10.281	A.sum()=0.999399
# alpha=50118.723	chi2/dof=6.644	A.sum()=0.999865
# alpha=89125.094	chi2/dof=13.363	A.sum()=0.999766
# alpha=89125.094	chi2/dof=13.089	A.sum()=0.999967
# alpha=56234.133	chi2/dof=7.742	A.sum()=0.999554
# alpha=63095.734	chi2/dof=8.327	A.sum()=0.999144
# alpha=63095.734	chi2/dof=7.732	A.sum()=0.999949
# alpha=63095.734	chi2/dof=8.448	A.sum()=0.999541
# alpha=63095.734	chi2/dof=8.498	A.sum()=0.999808
# alpha=63095.734	chi2/dof=6.813	A.sum()=0.999899
# alpha=44.668	chi2/dof=0.991	A.sum()=0.999676
# alpha=56234.133	chi2/dof=7.735	A.sum()=0.999894
# alpha=79432.823	chi2/dof=10.641	A.sum()=0.999626
# alpha=79432.823	chi2/dof=10.076	A.sum()=1.000054
# alpha=79432.823	chi2/dof=12.106	A.sum()=0.999782
# alpha=79432.823	chi2/dof=11.869	A.sum()=0.999780
# alpha=70794.578	chi2/dof=9.165	A.sum()=0.999979
# alpha=63095.734	chi2/dof=10.876	A.sum()=0.999621
# alpha=56234.133	chi2/dof=9.520	A.sum()=0.999637
# alpha=79432.823	chi2/dof=14.205	A.sum()=0.999547
# alpha=70794.578	chi2/dof=12.411	A.sum()=0.999356
# alpha=28183.829	chi2/dof=4.839	A.sum()=0.999696
# alpha=70794.578	chi2/dof=11.582	A.sum()=0.999771
# alpha=70794.578	chi2/dof=10.568	A.sum()=0.999829
# alpha=70794.578	chi2/dof=10.080	A.sum()=0.999647
# alpha=70794.578	chi2/dof=13.028	A.sum()=0.999899
# alpha=89125.094	chi2/dof=13.213	A.sum()=0.999893
# alpha=70794.578	chi2/dof=10.958	A.sum()=0.999742
# alpha=56234.133	chi2/dof=8.790	A.sum()=0.999627
# alpha=79432.823	chi2/dof=13.019	A.sum()=0.999892
# alpha=89125.094	chi2/dof=13.258	A.sum()=0.999716
# alpha=177.828	chi2/dof=0.580	A.sum()=0.999815
# alpha=70794.578	chi2/dof=12.186	A.sum()=0.999651
# alpha=79432.823	chi2/dof=12.966	A.sum()=0.999497
# alpha=79432.823	chi2/dof=12.861	A.sum()=0.999731
# alpha=79432.823	chi2/dof=12.765	A.sum()=0.999697
# alpha=70794.578	chi2/dof=10.926	A.sum()=1.000041
# alpha=100000.000	chi2/dof=14.897	A.sum()=0.999452
# alpha=56234.133	chi2/dof=8.930	A.sum()=0.999717
# alpha=79432.823	chi2/dof=14.404	A.sum()=0.999855
# alpha=79432.823	chi2/dof=13.120	A.sum()=0.999791
# alpha=50118.723	chi2/dof=7.399	A.sum()=0.999429
# alpha=89125.094	chi2/dof=12.201	A.sum()=0.999948
# alpha=63095.734	chi2/dof=9.201	A.sum()=1.000048
# alpha=70794.578	chi2/dof=12.343	A.sum()=0.999736
# alpha=50118.723	chi2/dof=7.313	A.sum()=1.000009
# alpha=100000.000	chi2/dof=15.948	A.sum()=0.999544
# alpha=100.000	chi2/dof=0.453	A.sum()=0.999783
# alpha=100000.000	chi2/dof=13.606	A.sum()=0.999762
# alpha=89125.094	chi2/dof=13.417	A.sum()=0.999839
# alpha=79432.823	chi2/dof=10.143	A.sum()=0.999965
# alpha=50.119	chi2/dof=1.344	A.sum()=0.999622
# alpha=70794.578	chi2/dof=13.442	A.sum()=0.999860
# alpha=70794.578	chi2/dof=10.106	A.sum()=0.999846
# alpha=63095.734	chi2/dof=7.945	A.sum()=0.999719
# alpha=79432.823	chi2/dof=12.062	A.sum()=0.999676
# alpha=70794.578	chi2/dof=9.868	A.sum()=0.999663
# alpha=79432.823	chi2/dof=13.426	A.sum()=1.000134
# alpha=50118.723	chi2/dof=7.249	A.sum()=0.999874
# alpha=70794.578	chi2/dof=8.044	A.sum()=0.999637
# alpha=89125.094	chi2/dof=14.363	A.sum()=0.999905
# alpha=50118.723	chi2/dof=7.803	A.sum()=0.999841
# alpha=50118.723	chi2/dof=6.945	A.sum()=0.999593
# alpha=63095.734	chi2/dof=9.577	A.sum()=1.000002
# alpha=89125.094	chi2/dof=11.017	A.sum()=0.999989
# alpha=44668.359	chi2/dof=6.367	A.sum()=0.999906
# alpha=56234.133	chi2/dof=8.589	A.sum()=0.999825
# alpha=56234.133	chi2/dof=8.106	A.sum()=0.999932
# alpha=63095.734	chi2/dof=9.273	A.sum()=0.999281
# alpha=70794.578	chi2/dof=8.392	A.sum()=0.999972
# alpha=63095.734	chi2/dof=9.422	A.sum()=0.999597
# alpha=89125.094	chi2/dof=13.215	A.sum()=0.999916
# alpha=63095.734	chi2/dof=8.712	A.sum()=0.999860
# alpha=56234.133	chi2/dof=8.407	A.sum()=0.999867
# alpha=70794.578	chi2/dof=9.816	A.sum()=0.999735
# alpha=56234.133	chi2/dof=8.277	A.sum()=0.999350
# alpha=56234.133	chi2/dof=6.724	A.sum()=0.999861
# alpha=50118.723	chi2/dof=8.168	A.sum()=0.999808
# alpha=79432.823	chi2/dof=12.710	A.sum()=0.999956
# alpha=79432.823	chi2/dof=13.772	A.sum()=0.999507
# alpha=70794.578	chi2/dof=10.116	A.sum()=0.999959
# alpha=70794.578	chi2/dof=9.789	A.sum()=0.999720
# alpha=56234.133	chi2/dof=8.788	A.sum()=0.999642
# alpha=63095.734	chi2/dof=8.155	A.sum()=1.000016
# alpha=63095.734	chi2/dof=10.796	A.sum()=0.999586
# alpha=70794.578	chi2/dof=9.467	A.sum()=0.999855
# alpha=79432.823	chi2/dof=11.019	A.sum()=0.999862
# alpha=63095.734	chi2/dof=9.574	A.sum()=0.999664
# alpha=63095.734	chi2/dof=8.668	A.sum()=0.999552
# alpha=56234.133	chi2/dof=7.979	A.sum()=0.999592
# alpha=79432.823	chi2/dof=12.137	A.sum()=0.999940
# alpha=63095.734	chi2/dof=8.193	A.sum()=0.999886
# alpha=56234.133	chi2/dof=7.580	A.sum()=0.999861
# alpha=70794.578	chi2/dof=10.374	A.sum()=0.999789
# alpha=70794.578	chi2/dof=9.517	A.sum()=0.999848
# alpha=50118.723	chi2/dof=7.541	A.sum()=1.000045
# alpha=63095.734	chi2/dof=9.310	A.sum()=0.999963
# alpha=35481.339	chi2/dof=6.436	A.sum()=0.999477
# alpha=89125.094	chi2/dof=13.963	A.sum()=0.999864
# alpha=70794.578	chi2/dof=10.984	A.sum()=1.000007
# alpha=89125.094	chi2/dof=14.832	A.sum()=0.999829
# alpha=70794.578	chi2/dof=10.420	A.sum()=0.999827
# alpha=70794.578	chi2/dof=9.829	A.sum()=0.999382
# alpha=56234.133	chi2/dof=7.655	A.sum()=0.999792
# alpha=70794.578	chi2/dof=8.857	A.sum()=0.999961
# alpha=79432.823	chi2/dof=10.701	A.sum()=1.000017
# alpha=70794.578	chi2/dof=10.243	A.sum()=0.999436
# alpha=79432.823	chi2/dof=12.140	A.sum()=0.999813
# alpha=63095.734	chi2/dof=10.497	A.sum()=0.999903
# alpha=63095.734	chi2/dof=9.930	A.sum()=0.999600
# alpha=50118.723	chi2/dof=6.736	A.sum()=0.999751
# alpha=63095.734	chi2/dof=8.356	A.sum()=0.999734
# alpha=70794.578	chi2/dof=10.388	A.sum()=0.999906
# alpha=70794.578	chi2/dof=11.329	A.sum()=0.999769
# alpha=63095.734	chi2/dof=8.882	A.sum()=0.999572
# alpha=89125.094	chi2/dof=13.366	A.sum()=0.999888
# alpha=50118.723	chi2/dof=5.986	A.sum()=1.000119
# alpha=79432.823	chi2/dof=12.462	A.sum()=0.999968
# alpha=70794.578	chi2/dof=10.014	A.sum()=0.999685
# alpha=63095.734	chi2/dof=8.190	A.sum()=0.999979
# alpha=70794.578	chi2/dof=9.702	A.sum()=0.999668
# alpha=79432.823	chi2/dof=9.957	A.sum()=0.999736
# alpha=63095.734	chi2/dof=11.048	A.sum()=0.999797
# alpha=56234.133	chi2/dof=7.211	A.sum()=0.999727
# alpha=79432.823	chi2/dof=11.604	A.sum()=0.999861
# alpha=79432.823	chi2/dof=12.512	A.sum()=0.999569
# alpha=70794.578	chi2/dof=10.335	A.sum()=0.999874
# alpha=70794.578	chi2/dof=8.480	A.sum()=0.999733
# alpha=56234.133	chi2/dof=9.335	A.sum()=0.999980
# alpha=56234.133	chi2/dof=7.964	A.sum()=0.999670
# alpha=56234.133	chi2/dof=7.322	A.sum()=0.999500
# alpha=56234.133	chi2/dof=7.632	A.sum()=0.999829
# alpha=50118.723	chi2/dof=8.222	A.sum()=0.999223
# alpha=70794.578	chi2/dof=8.476	A.sum()=0.999536
# alpha=56234.133	chi2/dof=6.942	A.sum()=0.999961
# alpha=100000.000	chi2/dof=14.521	A.sum()=0.999815
# alpha=63095.734	chi2/dof=9.702	A.sum()=0.999818
# alpha=56234.133	chi2/dof=8.023	A.sum()=0.999621
# alpha=63095.734	chi2/dof=10.109	A.sum()=0.999840
# alpha=70794.578	chi2/dof=10.948	A.sum()=0.999762
# alpha=63095.734	chi2/dof=8.782	A.sum()=1.000029
# alpha=79432.823	chi2/dof=9.957	A.sum()=1.000057
# alpha=50118.723	chi2/dof=6.779	A.sum()=0.999680
# alpha=44668.359	chi2/dof=7.424	A.sum()=0.999464
# alpha=50118.723	chi2/dof=7.445	A.sum()=0.999995
# alpha=70794.578	chi2/dof=12.059	A.sum()=0.999604
# alpha=50118.723	chi2/dof=8.368	A.sum()=0.999694
# alpha=56234.133	chi2/dof=7.513	A.sum()=0.999972
# alpha=70794.578	chi2/dof=12.831	A.sum()=0.999649
# alpha=89125.094	chi2/dof=13.796	A.sum()=0.999817
# alpha=70794.578	chi2/dof=10.031	A.sum()=0.999968
# alpha=63095.734	chi2/dof=8.366	A.sum()=0.999658
# alpha=70794.578	chi2/dof=9.974	A.sum()=0.999662
# alpha=63095.734	chi2/dof=9.077	A.sum()=0.999908
# alpha=100000.000	chi2/dof=14.009	A.sum()=0.999822
# alpha=89125.094	chi2/dof=12.273	A.sum()=0.999959
# alpha=50118.723	chi2/dof=8.097	A.sum()=0.999763
# alpha=70794.578	chi2/dof=9.622	A.sum()=0.999744
# alpha=70794.578	chi2/dof=11.822	A.sum()=0.999713
# alpha=63095.734	chi2/dof=8.701	A.sum()=0.999906
# alpha=70794.578	chi2/dof=9.966	A.sum()=0.999981
# alpha=63095.734	chi2/dof=10.308	A.sum()=0.999842
# alpha=50118.723	chi2/dof=6.670	A.sum()=1.000035
# alpha=56234.133	chi2/dof=7.585	A.sum()=0.999714
# alpha=141.254	chi2/dof=0.379	A.sum()=0.999854
# alpha=56234.133	chi2/dof=7.706	A.sum()=0.999902
# alpha=50118.723	chi2/dof=7.378	A.sum()=0.999840
# alpha=50118.723	chi2/dof=6.627	A.sum()=0.999663
# alpha=44668.359	chi2/dof=6.078	A.sum()=0.999712
# alpha=50118.723	chi2/dof=7.687	A.sum()=0.999678
# alpha=63095.734	chi2/dof=9.297	A.sum()=0.999399
# alpha=70794.578	chi2/dof=8.229	A.sum()=0.999917
# alpha=70794.578	chi2/dof=11.448	A.sum()=0.999156
# alpha=63095.734	chi2/dof=9.545	A.sum()=0.999676
# alpha=56234.133	chi2/dof=6.844	A.sum()=0.999975
# alpha=56234.133	chi2/dof=7.708	A.sum()=0.999893
# alpha=56234.133	chi2/dof=7.589	A.sum()=0.999632
# alpha=56234.133	chi2/dof=7.234	A.sum()=0.999708
# alpha=70794.578	chi2/dof=9.644	A.sum()=0.999978
# ../../../../project_data/newtune/4*4U8/tp0beta2.5/n1/
# 250000.0
# 800/800 complete bins
# nbin=800	<sign>=1.0
# 200000000.0 total samples
# jeje
# alpha=11220.185	chi2/dof=2.709	A.sum()=0.999169
# jkjk
# alpha=1258.925	chi2/dof=1.242	A.sum()=1.001202
# jpjp
# alpha=12589.254	chi2/dof=2.718	A.sum()=1.000108
# j0j0
# alpha=31622.777	chi2/dof=3.275	A.sum()=1.000108
# 250000.0
# 800/800 complete bins
# nbin=800	<sign>=1.0
# 200000000.0 total samples
# jeje
# alpha=12589.254	chi2/dof=3.734	A.sum()=0.999567
# alpha=15848.932	chi2/dof=3.808	A.sum()=0.998542
# alpha=19952.623	chi2/dof=5.944	A.sum()=0.999072
# alpha=7079.458	chi2/dof=2.272	A.sum()=0.999054
# alpha=14125.375	chi2/dof=3.693	A.sum()=0.999131
# alpha=12589.254	chi2/dof=3.737	A.sum()=0.999317
# alpha=15848.932	chi2/dof=3.889	A.sum()=1.000000
# alpha=15848.932	chi2/dof=4.781	A.sum()=0.998908
# alpha=15848.932	chi2/dof=3.622	A.sum()=0.999854
# alpha=31622.777	chi2/dof=8.057	A.sum()=1.000052
# alpha=15848.932	chi2/dof=4.019	A.sum()=0.999418
# alpha=28183.829	chi2/dof=7.523	A.sum()=0.998272
# alpha=10000.000	chi2/dof=3.321	A.sum()=0.998908
# alpha=15848.932	chi2/dof=4.939	A.sum()=0.998379
# alpha=12589.254	chi2/dof=4.758	A.sum()=0.998528
# alpha=12589.254	chi2/dof=3.253	A.sum()=0.999711
# alpha=15848.932	chi2/dof=3.924	A.sum()=0.998505
# alpha=17782.794	chi2/dof=4.171	A.sum()=1.000232
# alpha=14125.375	chi2/dof=4.645	A.sum()=0.998783
# alpha=15848.932	chi2/dof=3.865	A.sum()=0.999227
# alpha=14125.375	chi2/dof=2.516	A.sum()=0.999581
# alpha=12589.254	chi2/dof=3.263	A.sum()=0.999712
# alpha=14125.375	chi2/dof=4.667	A.sum()=1.000288
# alpha=12589.254	chi2/dof=3.390	A.sum()=0.999405
# alpha=15848.932	chi2/dof=4.979	A.sum()=0.998587
# alpha=15848.932	chi2/dof=3.706	A.sum()=0.999007
# alpha=6309.573	chi2/dof=1.802	A.sum()=0.999212
# alpha=22387.211	chi2/dof=6.324	A.sum()=0.999503
# alpha=22387.211	chi2/dof=5.433	A.sum()=0.998656
# alpha=15848.932	chi2/dof=3.867	A.sum()=0.998842
# alpha=19952.623	chi2/dof=5.015	A.sum()=1.000786
# alpha=15848.932	chi2/dof=4.462	A.sum()=1.000650
# alpha=14125.375	chi2/dof=3.441	A.sum()=0.999302
# alpha=17782.794	chi2/dof=4.955	A.sum()=0.997433
# alpha=17782.794	chi2/dof=4.070	A.sum()=0.998407
# alpha=17782.794	chi2/dof=4.981	A.sum()=0.999692
# alpha=17782.794	chi2/dof=4.576	A.sum()=1.000279
# alpha=17782.794	chi2/dof=4.724	A.sum()=0.998301
# alpha=17782.794	chi2/dof=4.159	A.sum()=0.999186
# alpha=14125.375	chi2/dof=3.275	A.sum()=0.999573
# alpha=15848.932	chi2/dof=4.561	A.sum()=0.999765
# alpha=14125.375	chi2/dof=3.906	A.sum()=1.000612
# alpha=15848.932	chi2/dof=3.673	A.sum()=1.000887
# alpha=22387.211	chi2/dof=6.489	A.sum()=1.000285
# alpha=19952.623	chi2/dof=4.823	A.sum()=0.999115
# alpha=19952.623	chi2/dof=5.680	A.sum()=0.998127
# alpha=22387.211	chi2/dof=6.858	A.sum()=0.999437
# alpha=15848.932	chi2/dof=4.523	A.sum()=1.001032
# alpha=22387.211	chi2/dof=5.596	A.sum()=0.999435
# alpha=7079.458	chi2/dof=2.646	A.sum()=0.998684
# alpha=14125.375	chi2/dof=3.760	A.sum()=0.998215
# alpha=11220.185	chi2/dof=3.017	A.sum()=0.998502
# alpha=19952.623	chi2/dof=5.752	A.sum()=0.999404
# alpha=14125.375	chi2/dof=3.705	A.sum()=0.999558
# alpha=15848.932	chi2/dof=3.663	A.sum()=0.998999
# alpha=14125.375	chi2/dof=3.713	A.sum()=0.999025
# alpha=14125.375	chi2/dof=4.172	A.sum()=0.998890
# alpha=15848.932	chi2/dof=4.373	A.sum()=0.999005
# alpha=17782.794	chi2/dof=5.008	A.sum()=0.999504
# alpha=17782.794	chi2/dof=4.015	A.sum()=0.999592
# alpha=15848.932	chi2/dof=4.017	A.sum()=0.998363
# alpha=15848.932	chi2/dof=4.021	A.sum()=0.999697
# alpha=14125.375	chi2/dof=4.147	A.sum()=0.999575
# alpha=14125.375	chi2/dof=4.410	A.sum()=1.000793
# alpha=15848.932	chi2/dof=4.181	A.sum()=0.998601
# alpha=12589.254	chi2/dof=3.404	A.sum()=1.000695
# alpha=17782.794	chi2/dof=6.091	A.sum()=0.998559
# alpha=12589.254	chi2/dof=3.166	A.sum()=0.999653
# alpha=1000.000	chi2/dof=1.191	A.sum()=0.999902
# alpha=17782.794	chi2/dof=4.652	A.sum()=0.997546
# alpha=1122.018	chi2/dof=1.190	A.sum()=1.000739
# alpha=12589.254	chi2/dof=3.563	A.sum()=0.999035
# alpha=17782.794	chi2/dof=4.914	A.sum()=1.000370
# alpha=19952.623	chi2/dof=5.072	A.sum()=0.999641
# alpha=15848.932	chi2/dof=4.718	A.sum()=1.001087
# alpha=14125.375	chi2/dof=4.510	A.sum()=0.999359
# alpha=11220.185	chi2/dof=3.122	A.sum()=0.999862
# alpha=19952.623	chi2/dof=5.095	A.sum()=0.999125
# alpha=22387.211	chi2/dof=6.305	A.sum()=1.000380
# alpha=19952.623	chi2/dof=6.241	A.sum()=0.999696
# alpha=17782.794	chi2/dof=4.591	A.sum()=0.998724
# alpha=14125.375	chi2/dof=3.273	A.sum()=0.999618
# alpha=8912.509	chi2/dof=2.844	A.sum()=0.999661
# alpha=15848.932	chi2/dof=4.103	A.sum()=1.000571
# alpha=17782.794	chi2/dof=4.943	A.sum()=0.999814
# alpha=17782.794	chi2/dof=4.872	A.sum()=0.999129
# alpha=14125.375	chi2/dof=3.306	A.sum()=0.999465
# alpha=15848.932	chi2/dof=4.328	A.sum()=0.998438
# alpha=22387.211	chi2/dof=6.423	A.sum()=0.999103
# alpha=22387.211	chi2/dof=6.077	A.sum()=0.998229
# alpha=8912.509	chi2/dof=2.805	A.sum()=0.999949
# alpha=15848.932	chi2/dof=3.751	A.sum()=0.998820
# alpha=12589.254	chi2/dof=3.716	A.sum()=0.999064
# alpha=19952.623	chi2/dof=4.658	A.sum()=0.998991
# alpha=15848.932	chi2/dof=4.160	A.sum()=0.998277
# alpha=11220.185	chi2/dof=3.036	A.sum()=1.000131
# alpha=15848.932	chi2/dof=3.719	A.sum()=0.998730
# alpha=15848.932	chi2/dof=4.395	A.sum()=0.999299
# alpha=15848.932	chi2/dof=3.916	A.sum()=0.999482
# alpha=6309.573	chi2/dof=2.908	A.sum()=0.999293
# alpha=22387.211	chi2/dof=6.075	A.sum()=1.000226
# alpha=8912.509	chi2/dof=3.235	A.sum()=0.999759
# alpha=12589.254	chi2/dof=3.276	A.sum()=0.998830
# alpha=17782.794	chi2/dof=4.459	A.sum()=0.998449
# alpha=11220.185	chi2/dof=2.857	A.sum()=0.999199
# alpha=14125.375	chi2/dof=3.558	A.sum()=0.999159
# alpha=11220.185	chi2/dof=3.099	A.sum()=1.001522
# alpha=17782.794	chi2/dof=4.997	A.sum()=0.998620
# alpha=1000.000	chi2/dof=1.131	A.sum()=1.000131
# alpha=22387.211	chi2/dof=5.794	A.sum()=0.999652
# alpha=19952.623	chi2/dof=4.356	A.sum()=0.998861
# alpha=17782.794	chi2/dof=4.828	A.sum()=0.999153
# alpha=14125.375	chi2/dof=3.888	A.sum()=0.999876
# alpha=17782.794	chi2/dof=4.772	A.sum()=0.998595
# alpha=7943.282	chi2/dof=1.983	A.sum()=0.998474
# alpha=14125.375	chi2/dof=3.987	A.sum()=1.000079
# alpha=22387.211	chi2/dof=7.176	A.sum()=0.997996
# alpha=11220.185	chi2/dof=3.365	A.sum()=1.000642
# alpha=19952.623	chi2/dof=4.623	A.sum()=0.998326
# alpha=794.328	chi2/dof=1.170	A.sum()=0.999804
# alpha=15848.932	chi2/dof=4.389	A.sum()=0.998910
# alpha=15848.932	chi2/dof=4.490	A.sum()=0.999047
# alpha=17782.794	chi2/dof=4.276	A.sum()=0.998602
# alpha=15848.932	chi2/dof=4.326	A.sum()=0.999562
# alpha=12589.254	chi2/dof=3.439	A.sum()=0.998484
# alpha=10000.000	chi2/dof=2.596	A.sum()=0.999184
# alpha=1258.925	chi2/dof=1.082	A.sum()=0.999073
# alpha=14125.375	chi2/dof=3.749	A.sum()=0.999740
# alpha=11220.185	chi2/dof=3.188	A.sum()=0.999034
# alpha=10000.000	chi2/dof=3.513	A.sum()=0.999227
# alpha=17782.794	chi2/dof=4.625	A.sum()=0.999326
# alpha=19952.623	chi2/dof=5.665	A.sum()=0.999556
# alpha=14125.375	chi2/dof=3.243	A.sum()=0.999133
# alpha=15848.932	chi2/dof=3.252	A.sum()=1.000403
# alpha=22387.211	chi2/dof=6.772	A.sum()=0.999621
# alpha=19952.623	chi2/dof=6.067	A.sum()=0.998816
# alpha=1258.925	chi2/dof=1.133	A.sum()=0.999569
# alpha=14125.375	chi2/dof=3.684	A.sum()=0.999712
# alpha=17782.794	chi2/dof=4.513	A.sum()=0.999242
# alpha=15848.932	chi2/dof=3.596	A.sum()=0.998823
# alpha=17782.794	chi2/dof=6.276	A.sum()=0.999479
# alpha=17782.794	chi2/dof=4.436	A.sum()=0.999888
# alpha=19952.623	chi2/dof=5.506	A.sum()=0.998831
# alpha=12589.254	chi2/dof=3.058	A.sum()=0.999595
# alpha=15848.932	chi2/dof=3.708	A.sum()=0.999551
# alpha=14125.375	chi2/dof=4.435	A.sum()=0.999223
# alpha=8912.509	chi2/dof=2.584	A.sum()=0.999275
# alpha=19952.623	chi2/dof=5.587	A.sum()=0.998367
# alpha=14125.375	chi2/dof=3.508	A.sum()=0.998164
# alpha=12589.254	chi2/dof=3.044	A.sum()=0.999502
# alpha=10000.000	chi2/dof=2.689	A.sum()=0.998939
# alpha=15848.932	chi2/dof=4.104	A.sum()=0.999087
# alpha=1000.000	chi2/dof=1.064	A.sum()=1.000556
# alpha=12589.254	chi2/dof=3.329	A.sum()=0.998690
# alpha=14125.375	chi2/dof=4.763	A.sum()=0.999454
# alpha=19952.623	chi2/dof=5.284	A.sum()=0.998452
# alpha=12589.254	chi2/dof=2.968	A.sum()=0.999243
# alpha=11220.185	chi2/dof=3.200	A.sum()=0.999553
# alpha=10000.000	chi2/dof=2.662	A.sum()=0.999756
# alpha=10000.000	chi2/dof=2.568	A.sum()=0.999576
# alpha=11220.185	chi2/dof=3.027	A.sum()=0.998899
# alpha=17782.794	chi2/dof=4.234	A.sum()=0.998840
# alpha=11220.185	chi2/dof=3.429	A.sum()=0.999029
# alpha=15848.932	chi2/dof=3.456	A.sum()=0.997964
# alpha=8912.509	chi2/dof=2.186	A.sum()=1.000051
# alpha=1258.925	chi2/dof=1.634	A.sum()=0.998829
# alpha=10000.000	chi2/dof=2.434	A.sum()=0.999457
# alpha=19952.623	chi2/dof=6.366	A.sum()=0.997960
# alpha=15848.932	chi2/dof=4.298	A.sum()=0.998370
# alpha=19952.623	chi2/dof=5.017	A.sum()=0.999684
# alpha=17782.794	chi2/dof=5.080	A.sum()=1.000007
# alpha=14125.375	chi2/dof=3.603	A.sum()=0.998617
# alpha=12589.254	chi2/dof=3.709	A.sum()=0.998383
# alpha=12589.254	chi2/dof=3.592	A.sum()=0.999127
# alpha=6309.573	chi2/dof=2.226	A.sum()=0.998533
# alpha=1122.018	chi2/dof=0.967	A.sum()=0.998757
# alpha=10000.000	chi2/dof=3.851	A.sum()=0.999991
# alpha=7079.458	chi2/dof=2.328	A.sum()=0.999247
# alpha=14125.375	chi2/dof=3.421	A.sum()=0.999211
# alpha=17782.794	chi2/dof=3.842	A.sum()=0.998958
# alpha=28183.829	chi2/dof=7.727	A.sum()=0.999259
# alpha=17782.794	chi2/dof=4.469	A.sum()=0.999565
# alpha=1258.925	chi2/dof=1.159	A.sum()=0.999497
# alpha=15848.932	chi2/dof=3.662	A.sum()=1.000500
# ...
# clipping 1 W values to W.min()*100000000.0
# alpha=89.125	chi2/dof=0.675	A.sum()=0.999895
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=0.930	A.sum()=0.999658
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.546	A.sum()=0.999471
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.000	A.sum()=0.999155
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.497	A.sum()=0.999408
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.080	A.sum()=0.999314
# clipping 1 W values to W.min()*100000000.0
# alpha=251.189	chi2/dof=0.724	A.sum()=0.999310
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.196	A.sum()=0.999386
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=0.915	A.sum()=0.999206
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.541	A.sum()=0.999293
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.154	A.sum()=0.999184
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.503	A.sum()=0.999392
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.495	A.sum()=0.999152
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.040	A.sum()=0.999818
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.267	A.sum()=0.999019
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.254	A.sum()=0.999521
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.168	A.sum()=0.999290
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.219	A.sum()=0.999638
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.229	A.sum()=0.999630
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.276	A.sum()=0.999219
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.199	A.sum()=0.999608
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=0.952	A.sum()=0.999325
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=1.091	A.sum()=0.999409
# clipping 1 W values to W.min()*100000000.0
# alpha=7079.458	chi2/dof=1.061	A.sum()=0.999397
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.295	A.sum()=0.999515
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.228	A.sum()=0.999302
# clipping 1 W values to W.min()*100000000.0
# alpha=4466835.922	chi2/dof=1.209	A.sum()=0.999352
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.327	A.sum()=0.999215
# clipping 1 W values to W.min()*100000000.0
# alpha=1412.538	chi2/dof=1.339	A.sum()=0.999687
# clipping 1 W values to W.min()*100000000.0
# alpha=141.254	chi2/dof=1.089	A.sum()=0.999433
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.510	A.sum()=0.999399
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.253	A.sum()=0.999481
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.022	A.sum()=0.999369
# clipping 1 W values to W.min()*100000000.0
# alpha=1778.279	chi2/dof=1.143	A.sum()=0.999239
# clipping 1 W values to W.min()*100000000.0
# alpha=17782.794	chi2/dof=1.162	A.sum()=0.999679
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.076	A.sum()=0.999608
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.601	A.sum()=0.999417
# clipping 1 W values to W.min()*100000000.0
# alpha=112.202	chi2/dof=1.047	A.sum()=0.999106
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.253	A.sum()=0.999455
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=0.810	A.sum()=0.999482
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.232	A.sum()=0.999740
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.181	A.sum()=0.998935
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.041	A.sum()=0.999154
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=1.212	A.sum()=0.998617
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.001	A.sum()=0.999357
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.438	A.sum()=0.999013
# clipping 1 W values to W.min()*100000000.0
# alpha=17.783	chi2/dof=1.047	A.sum()=0.998880
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.381	A.sum()=0.999162
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.151	A.sum()=0.998890
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=1.398	A.sum()=0.999491
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=0.937	A.sum()=0.999582
# clipping 1 W values to W.min()*100000000.0
# alpha=316227.766	chi2/dof=0.974	A.sum()=0.999777
# clipping 1 W values to W.min()*100000000.0
# alpha=446.684	chi2/dof=1.166	A.sum()=0.999693
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=0.873	A.sum()=0.999346
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.599	A.sum()=0.998795
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.640	A.sum()=0.998578
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.024	A.sum()=0.999302
# clipping 1 W values to W.min()*100000000.0
# alpha=223872.114	chi2/dof=1.325	A.sum()=0.999034
# clipping 1 W values to W.min()*100000000.0
# alpha=281838.293	chi2/dof=1.174	A.sum()=0.999177
# clipping 1 W values to W.min()*100000000.0
# alpha=2511.886	chi2/dof=1.299	A.sum()=0.999035
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=0.979	A.sum()=0.999186
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.165	A.sum()=0.999004
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=1.684	A.sum()=0.999151
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=0.927	A.sum()=0.999003
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=0.931	A.sum()=0.999357
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.099	A.sum()=0.999557
# clipping 1 W values to W.min()*100000000.0
# alpha=177.828	chi2/dof=0.818	A.sum()=0.999870
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.188	A.sum()=0.999378
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.312	A.sum()=0.999405
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.406	A.sum()=0.999473
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=1.077	A.sum()=0.999478
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.260	A.sum()=0.999357
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.269	A.sum()=0.999652
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.162	A.sum()=0.999159
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=0.918	A.sum()=0.999427
# clipping 1 W values to W.min()*100000000.0
# alpha=281838.293	chi2/dof=1.017	A.sum()=0.999549
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.017	A.sum()=0.999153
# clipping 1 W values to W.min()*100000000.0
# alpha=89.125	chi2/dof=1.054	A.sum()=0.999711
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=0.793	A.sum()=0.999590
# clipping 1 W values to W.min()*100000000.0
# alpha=281838.293	chi2/dof=1.205	A.sum()=0.999154
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.143	A.sum()=0.999420
# clipping 1 W values to W.min()*100000000.0
# alpha=2238.721	chi2/dof=1.198	A.sum()=0.999320
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=0.875	A.sum()=0.999319
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=0.934	A.sum()=0.999249
# clipping 1 W values to W.min()*100000000.0
# alpha=17782.794	chi2/dof=0.766	A.sum()=0.999885
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=0.901	A.sum()=0.999866
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.193	A.sum()=0.999499
# clipping 1 W values to W.min()*100000000.0
# alpha=14.125	chi2/dof=0.617	A.sum()=0.998997
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=0.975	A.sum()=0.999301
# clipping 1 W values to W.min()*100000000.0
# alpha=11220.185	chi2/dof=0.866	A.sum()=0.999557
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.314	A.sum()=0.999479
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.427	A.sum()=0.999353
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.063	A.sum()=0.999503
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.097	A.sum()=0.999110
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.286	A.sum()=0.999521
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=0.985	A.sum()=0.999516
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.460	A.sum()=0.998910
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.292	A.sum()=0.999537
# clipping 1 W values to W.min()*100000000.0
# alpha=446.684	chi2/dof=1.305	A.sum()=0.999334
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.001	A.sum()=0.998943
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.198	A.sum()=0.999809
# clipping 1 W values to W.min()*100000000.0
# alpha=4466835.922	chi2/dof=1.343	A.sum()=0.999426
# clipping 1 W values to W.min()*100000000.0
# alpha=17782.794	chi2/dof=1.291	A.sum()=0.999603
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.206	A.sum()=0.999192
# clipping 1 W values to W.min()*100000000.0
# alpha=4466835.922	chi2/dof=1.421	A.sum()=0.999564
# clipping 1 W values to W.min()*100000000.0
# alpha=794.328	chi2/dof=0.731	A.sum()=0.999328
# clipping 1 W values to W.min()*100000000.0
# alpha=281838.293	chi2/dof=1.200	A.sum()=0.999445
# clipping 1 W values to W.min()*100000000.0
# alpha=1258.925	chi2/dof=1.053	A.sum()=0.999596
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.376	A.sum()=0.999204
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.133	A.sum()=0.999347
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.274	A.sum()=0.999292
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.188	A.sum()=0.999333
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.185	A.sum()=0.999233
# clipping 1 W values to W.min()*100000000.0
# alpha=177.828	chi2/dof=1.097	A.sum()=0.999308
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.323	A.sum()=0.999347
# clipping 1 W values to W.min()*100000000.0
# alpha=223872.114	chi2/dof=1.128	A.sum()=0.999017
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=0.935	A.sum()=0.999039
# clipping 1 W values to W.min()*100000000.0
# alpha=199.526	chi2/dof=1.094	A.sum()=0.999828
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=0.977	A.sum()=0.999104
# clipping 1 W values to W.min()*100000000.0
# alpha=223872.114	chi2/dof=1.213	A.sum()=0.999204
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=1.081	A.sum()=0.998947
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.354	A.sum()=0.999307
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.127	A.sum()=0.999231
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.302	A.sum()=0.999193
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.245	A.sum()=0.999363
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.284	A.sum()=0.999449
# clipping 1 W values to W.min()*100000000.0
# alpha=281838.293	chi2/dof=0.821	A.sum()=0.999590
# clipping 1 W values to W.min()*100000000.0
# alpha=251.189	chi2/dof=1.051	A.sum()=0.999420
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=0.668	A.sum()=0.999774
# clipping 1 W values to W.min()*100000000.0
# alpha=2238.721	chi2/dof=0.933	A.sum()=0.999248
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.200	A.sum()=0.999347
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=0.887	A.sum()=0.999240
# clipping 1 W values to W.min()*100000000.0
# alpha=22.387	chi2/dof=0.979	A.sum()=0.999707
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=0.963	A.sum()=0.999403
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.127	A.sum()=0.999229
# clipping 1 W values to W.min()*100000000.0
# alpha=17782.794	chi2/dof=1.266	A.sum()=0.999603
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=1.024	A.sum()=0.999563
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.113	A.sum()=0.999101
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.163	A.sum()=0.999039
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.217	A.sum()=0.999725
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=1.142	A.sum()=0.999600
# clipping 1 W values to W.min()*100000000.0
# alpha=17782.794	chi2/dof=1.377	A.sum()=0.999858
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=1.128	A.sum()=0.999265
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.369	A.sum()=0.999084
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.417	A.sum()=0.999163
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.135	A.sum()=0.999357
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.171	A.sum()=0.999167
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.202	A.sum()=0.999286
# clipping 1 W values to W.min()*100000000.0
# alpha=14125.375	chi2/dof=1.086	A.sum()=0.999559
# clipping 1 W values to W.min()*100000000.0
# alpha=6309573.445	chi2/dof=1.156	A.sum()=0.999718
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.786	A.sum()=0.999435
# clipping 1 W values to W.min()*100000000.0
# alpha=15848.932	chi2/dof=1.095	A.sum()=0.999511
# clipping 1 W values to W.min()*100000000.0
# alpha=19952.623	chi2/dof=1.320	A.sum()=0.999449
# clipping 1 W values to W.min()*100000000.0
# alpha=199.526	chi2/dof=0.934	A.sum()=0.999421
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.162	A.sum()=0.999278
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.277	A.sum()=0.999455
# clipping 1 W values to W.min()*100000000.0
# alpha=1258.925	chi2/dof=1.438	A.sum()=0.999564
# clipping 1 W values to W.min()*100000000.0
# alpha=281838.293	chi2/dof=1.195	A.sum()=0.999365
# clipping 1 W values to W.min()*100000000.0
# alpha=223872.114	chi2/dof=0.993	A.sum()=0.998725
# clipping 1 W values to W.min()*100000000.0
# alpha=281838.293	chi2/dof=1.174	A.sum()=0.999562
# clipping 1 W values to W.min()*100000000.0
# alpha=316227.766	chi2/dof=1.197	A.sum()=0.999435
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.606	A.sum()=0.999118
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.264	A.sum()=0.998938
# clipping 1 W values to W.min()*100000000.0
# alpha=12589.254	chi2/dof=0.724	A.sum()=0.999333
# clipping 1 W values to W.min()*100000000.0
# alpha=1584.893	chi2/dof=0.951	A.sum()=0.999638
# clipping 1 W values to W.min()*100000000.0
# alpha=56.234	chi2/dof=1.110	A.sum()=0.999105
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.361	A.sum()=0.999271
# clipping 1 W values to W.min()*100000000.0
# alpha=7943282.347	chi2/dof=1.251	A.sum()=0.999171
# clipping 1 W values to W.min()*100000000.0
# alpha=1122.018	chi2/dof=0.828	A.sum()=0.999573
# clipping 1 W values to W.min()*100000000.0
# alpha=5623413.252	chi2/dof=1.463	A.sum()=0.999548
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.279	A.sum()=0.999189
# clipping 1 W values to W.min()*100000000.0
# alpha=251188.643	chi2/dof=1.053	A.sum()=0.998957
# clipping 1 W values to W.min()*100000000.0
# alpha=7079457.844	chi2/dof=1.085	A.sum()=0.999306
# clipping 1 W values to W.min()*100000000.0
# alpha=5011872.336	chi2/dof=1.047	A.sum()=0.999039

# %%
# U=8
# bs=200
# tp=0


# w = np.load(f"wU={U:g}.npy")
# dw = np.load(f"dwU={U:g}.npy")

# prefix = "n1_annealing_single_alwaysBT"

# sitex = 4
# sitey = 4


# ns = np.array([1])
# betas = np.array([2,2.5,3,3.5,4,4.5,5,6,7,8,10])

# jeje,jkjk,jpjp,j0j0,C,chi,jejes,jkjks,jpjps,j0j0s,Cs,chis = loading(U,tp,sitex,sitey,prefix)
# mdls=None
# for i, n in enumerate(ns):
#     for j, b in enumerate(betas):
#         if b<8:
#             continue
#         path =  f"../../../../project_data/newtune/{sitex:g}*{sitey:g}U{U:g}/tp{tp:g}beta{b:g}/n{n:g}/"
#         saving(U,tp,b,n,i,j,sitex,sitey,bs,w,dw,jeje,jkjk,jpjp,
#                j0j0,C,chi,jejes,jkjks,jpjps,j0j0s,Cs,chis,prefix,mdls=mdls,path=path,modelstyle='annealing_single',alwaysBT=True)
